# %%
import os

# Your root path
NFL_path = '/content/drive/MyDrive/NFL_Prediction_System'
UTILS_PATH = os.path.join(NFL_path, 'src', 'utils')

# Create the directory
os.makedirs(UTILS_PATH, exist_ok=True)
print(f"Directory {UTILS_PATH} created (or already exists).")
# Out:
# Directory /content/drive/MyDrive/NFL_Prediction_System/src/utils created (or already exists).

# %%
# %%writefile /content/drive/MyDrive/NFL_Prediction_System/src/utils/config.py
from pathlib import Path

# --- THIS IS THE ONLY LINE YOU'LL EVER NEED TO CHANGE ---
# For Colab:
ROOT_DIR = Path('/content/drive/MyDrive/NFL_Prediction_System')

# For a local Mac:
# ROOT_DIR = Path('/Users/YourUser/Projects/NFL-Predictor')

# For a local Windows machine:
# ROOT_DIR = Path(r'C:\Users\YourUser\Projects\NFL-Predictor')
# --------------------------------------------------------


# --- ALL OTHER PATHS ARE BUILT FROM ROOT_DIR ---
# No need to edit anything below this line

DATA_DIR = ROOT_DIR / "data"

# Raw data
RAW_DATA_DIR = DATA_DIR / "raw"
RAW_GAMES_PATH = RAW_DATA_DIR / "games"
RAW_PLAYERS_PATH = RAW_DATA_DIR / "players"
RAW_TEAM_STATS_PATH = RAW_DATA_DIR / "team_stats"
RAW_EXTERNAL_PATH = RAW_DATA_DIR / "external"

# Cleaned data
CLEANED_DATA_DIR = DATA_DIR / "cleaned"
CLEANED_GAMES_PATH = CLEANED_DATA_DIR / "games"
CLEANED_PLAYERS_PATH = CLEANED_DATA_DIR / "players"
CLEANED_TEAMS_PATH = CLEANED_DATA_DIR / "teams"

# Feature data
FEATURES_DIR = DATA_DIR / "features"
FEATURES_TRAIN_PATH = FEATURES_DIR / "train"
FEATURES_VAL_PATH = FEATURES_DIR / "validation"
FEATURES_TEST_PATH = FEATURES_DIR / "test"

# Other project paths
MODELS_DIR = ROOT_DIR / "models"
OUTPUTS_DIR = ROOT_DIR / "outputs"
LOGS_DIR = ROOT_DIR / "logs"
NOTEBOOKS_DIR = ROOT_DIR / "notebooks"
SRC_DIR = ROOT_DIR / "src"
# Out:
# Writing /content/drive/MyDrive/NFL_Prediction_System/src/utils/config.py
